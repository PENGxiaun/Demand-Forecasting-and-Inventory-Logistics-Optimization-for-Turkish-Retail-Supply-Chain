# %% [markdown]
# <a href="https://colab.research.google.com/github/PENGxiaun/Demand-Forecasting-and-Inventory-Logistics-Optimization-for-Turkish-Retail-Supply-Chain/blob/main/data_cleaning%20code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # session1

# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")
print(response)

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
# download and read csv file
from google.colab import files
uploaded = files.upload()

# read csv file
import pandas as pd
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#      <input type="file" id="files-efa299d6-c11f-4f8e-b8b6-cabe59c07522" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-efa299d6-c11f-4f8e-b8b6-cabe59c07522">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 导入pandas库
import pandas as pd

# 老师给的泰坦尼克号数据链接
titanic_url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# 直接读取链接中的CSV数据
df = pd.read_csv(titanic_url)

# 查看数据前5行，验证是否读取成功
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd

# 你的目标数据链接
URL = "https://raw.githubusercontent.com/Datatil/Datasets/master/titanic.xls"
# 读取xls格式Excel文件，直接赋值给df
df = pd.read_excel(URL)

# 查看数据前5行，验证读取成功
print("数据读取成功，前5行内容：")
df.head()
# Out:
# 数据读取成功，前5行内容：
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
session2

# %%
# 导入Colab的文件上传工具
from google.colab import files

# 触发文件上传窗口
uploaded = files.upload()
# Out:
#      <input type="file" id="files-85e7d706-6b58-4a07-8509-a113ad027499" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85e7d706-6b58-4a07-8509-a113ad027499">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io  # 用于处理上传的文件流

# 读取上传的Excel文件（注意文件名要和你上传的一致）
df = pd.read_excel(io.BytesIO(uploaded['cereal_data.xls']))

# 查看数据前5行，确认读取成功
df.head()
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 0             Corn Chex   R    C     110.0      2.0  0.0   280.0    0.0
# 1           Corn Flakes   K    C     100.0      2.0  0.0   290.0    1.0
# 2         Rice Krispies   K    C     110.0      2.0  0.0   290.0    0.0
# 3             Special K   K  NaN     110.0      6.0  0.0   230.0    1.0
# 4  Multi-Grain Cheerios   G    C     100.0      2.0  1.0   220.0    2.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0   22.0     3.0    25.0      25.0    1.0     1.0   1.0  41.445019
# 1   21.0     2.0    35.0      25.0    1.0     1.0   1.0  45.863324
# 2   22.0     3.0    35.0      25.0    1.0     1.0   1.0  40.560159
# 3   16.0     3.0    55.0      25.0    1.0     1.0   1.0  53.131324
# 4   15.0     6.0    90.0      25.0    1.0     1.0   1.0  40.105965

# %%
print(df.tail())
# Out:
#                  name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 72  Grape Nuts Flakes   P    C     100.0      3.0  1.0   140.0    3.0   15.0
# 73          Rice Chex   R    C       NaN      1.0  0.0   240.0    0.0   23.0
# 74           Cheerios   G    C     110.0      6.0  2.0   290.0    2.0   17.0
# 75         Honey-comb   P    C     110.0      1.0  0.0   180.0    0.0   14.0
# 76                Kix   G    C     110.0      2.0  1.0   260.0    0.0   21.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 72     5.0    85.0      25.0    3.0     1.0  0.88  52.076897
# 73     2.0    30.0      25.0    1.0     1.0  1.13  41.998933
# 74     1.0   105.0      25.0    1.0     1.0  1.25  50.764999
# 75    11.0    35.0      25.0    1.0     1.0  1.33  28.742414
# 76     3.0    40.0      25.0    2.0     1.0  1.50  39.241114

# %%
df.shape
# Out:
# (77, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       73 non-null     object
#  2   type      71 non-null     object
#  3   calories  76 non-null     float64
#  4   protein   76 non-null     float64
#  5   fat       75 non-null     float64
#  6   sodium    76 non-null     float64
#  7   fiber     75 non-null     float64
#  8   carbo     75 non-null     float64
#  9   sugars    75 non-null     float64
#  10  potass    76 non-null     float64
#  11  vitamins  76 non-null     float64
#  12  shelf     76 non-null     float64
#  13  weight    74 non-null     float64
#  14  cups      76 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(13), object(3)
# memory usage: 9.8+ KB

# %%
# the cleanning process
# list of missing values by colum
df.isna().sum()
# Out:
# name        0
# mfr         4
# type        6
# calories    1
# protein     1
# fat         2
# sodium      1
# fiber       2
# carbo       2
# sugars      2
# potass      1
# vitamins    1
# shelf       1
# weight      3
# cups        1
# rating      0
# dtype: int64

# %%
# select th object columns
cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['name', 'mfr', 'type'], dtype='object')

# %%
###用每列的 ** 众数（mode）** 来填充该列的缺失值
cat_cols

for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# clean the object columns by the mode用每列的众数填充缺失值
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

df.isna().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    1
# protein     1
# fat         2
# sodium      1
# fiber       2
# carbo       2
# sugars      2
# potass      1
# vitamins    1
# shelf       1
# weight      3
# cups        1
# rating      0
# dtype: int64

# %%
# 1. 先定义分类列（之前已经定义过）
cat_cols = df.select_dtypes(include='object').columns

# 2. 定义数值列：筛选出所有数值型列
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

# 3. 用众数填充分类列的缺失值
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# 4. 用均值填充数值列的缺失值
for col in num_cols:
    df[col] = df[col].fillna(df[col].mean())

# %%
# 检查清洗后是否还有缺失值（输出每列缺失值数量）
df.isna().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %% [markdown]
# session3 模拟考试答案

# %%
# import required (all) libraries

# %%
# upload file
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-fad63f55-1939-44f6-ad3a-c9b7f13126a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fad63f55-1939-44f6-ad3a-c9b7f13126a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# read cereal excel file
df = pd.read_excel('cereal_data.xls')
df
# Out:
#                     name mfr type  calories  protein  fat  sodium  fiber  \
# 0              Corn Chex   R    C     110.0      2.0  0.0   280.0    0.0
# 1            Corn Flakes   K    C     100.0      2.0  0.0   290.0    1.0
# 2          Rice Krispies   K    C     110.0      2.0  0.0   290.0    0.0
# 3              Special K   K  NaN     110.0      6.0  0.0   230.0    1.0
# 4   Multi-Grain Cheerios   G    C     100.0      2.0  1.0   220.0    2.0
# ..                   ...  ..  ...       ...      ...  ...     ...    ...
# 72     Grape Nuts Flakes   P    C     100.0      3.0  1.0   140.0    3.0
# 73             Rice Chex   R    C       NaN      1.0  0.0   240.0    0.0
# 74              Cheerios   G    C     110.0      6.0  2.0   290.0    2.0
# 75            Honey-comb   P    C     110.0      1.0  0.0   180.0    0.0
# 76                   Kix   G    C     110.0      2.0  1.0   260.0    0.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# ...

# %%
# df dims
df.shape
# Out:
# (77, 16)

# %%
# df columns
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
# df information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       73 non-null     object
#  2   type      71 non-null     object
#  3   calories  76 non-null     float64
#  4   protein   76 non-null     float64
#  5   fat       75 non-null     float64
#  6   sodium    76 non-null     float64
#  7   fiber     75 non-null     float64
#  8   carbo     75 non-null     float64
#  9   sugars    75 non-null     float64
#  10  potass    76 non-null     float64
#  11  vitamins  76 non-null     float64
#  12  shelf     76 non-null     float64
#  13  weight    74 non-null     float64
#  14  cups      76 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(13), object(3)
# memory usage: 9.8+ KB

# %%
# Clean data-frame (df)

# %%
# list of missing values by columns
df.isnull().sum()
# Out:
# name        0
# mfr         4
# type        6
# calories    1
# protein     1
# fat         2
# sodium      1
# fiber       2
# carbo       2
# sugars      2
# potass      1
# vitamins    1
# shelf       1
# weight      3
# cups        1
# rating      0
# dtype: int64

# %%
# select the num columns
num_cols = df.select_dtypes(include=np.number).columns
num_cols
# Out:
# Index(['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars',
#        'potass', 'vitamins', 'shelf', 'weight', 'cups', 'rating'],
#       dtype='object')

# %%
# select the cat columns
cat_cols = df.select_dtypes(include=object).columns
cat_cols
# Out:
# Index(['name', 'mfr', 'type'], dtype='object')

# %%
# clean the num cols
for col in num_cols:
    df[col] = df[col].fillna(df[col].mean())

# %%
# clean the cat cols
for col in cat_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# list of missing values by columns
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
# print first and last six rows
df.head(6)
# Out:
#                    name mfr type  calories  protein  fat  sodium  fiber  \
# 0             Corn Chex   R    C     110.0      2.0  0.0   280.0    0.0
# 1           Corn Flakes   K    C     100.0      2.0  0.0   290.0    1.0
# 2         Rice Krispies   K    C     110.0      2.0  0.0   290.0    0.0
# 3             Special K   K    C     110.0      6.0  0.0   230.0    1.0
# 4  Multi-Grain Cheerios   G    C     100.0      2.0  1.0   220.0    2.0
# 5              Wheaties   G    C     100.0      3.0  1.0   200.0    3.0
#
#    carbo  sugars  potass  vitamins  shelf    weight  cups     rating
# 0   22.0     3.0    25.0      25.0    1.0  1.000000   1.0  41.445019
# 1   21.0     2.0    35.0      25.0    1.0  1.000000   1.0  45.863324
# 2   22.0     3.0    35.0      25.0    1.0  1.000000   1.0  40.560159
# 3   16.0     3.0    55.0      25.0    1.0  1.000000   1.0  53.131324
# 4   15.0     6.0    90.0      25.0    1.0  1.000000   1.0  40.105965
# ...

# %%
# Find the Minimum "calories" cereal name
min_cer_name = df[df["calories"] == df["calories"].min()]
min_cer_name
# 先通过 df["calories"].min() 找到 calories 列的最小值。
# 然后用布尔索引 df["calories"] == 最小值 筛选出所有卡路里等于最小值的行。
# 最后将这些行赋值给 min_cer_name 并打印出来。
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 26                Puffed Rice   Q    C      50.0      1.0  0.0     0.0    0.0
# 27               Puffed Wheat   Q    C      50.0      2.0  0.0     0.0    1.0
# 39  All-Bran with Extra Fiber   K    C      50.0      4.0  0.0   140.0   14.0
#
#     carbo  sugars  potass   vitamins  shelf  weight  cups     rating
# 26   13.0     0.0    15.0   0.000000    3.0     0.5   1.0  60.756112
# 27   10.0     0.0    50.0   0.000000    3.0     0.5   1.0  63.005645
# 39    8.0     0.0   330.0  28.289474    3.0     1.0   0.5  93.704912

# %%
# Print the list of cereal name with Sugars rate = 0
Zero_sug = df[df["sugars"] == 0]
Zero_sug
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 6      Cream of Wheat (Quick)   N    H     100.0      3.0  0.0    80.0    1.0
# 26                Puffed Rice   Q    C      50.0      1.0  0.0     0.0    0.0
# 27               Puffed Wheat   Q    C      50.0      2.0  0.0     0.0    1.0
# 28             Shredded Wheat   N    C      80.0      2.0  0.0     0.0    3.0
# 39  All-Bran with Extra Fiber   K    C      50.0      4.0  0.0   140.0   14.0
# 42  Shredded Wheat spoon size   N    C      90.0      3.0  0.0     0.0    3.0
# 43     Shredded Wheat 'n'Bran   N    C      90.0      3.0  0.0     0.0    4.0
#
#     carbo  sugars  potass   vitamins  shelf  weight  cups     rating
# 6    21.0     0.0    -1.0   0.000000    2.0    1.00  1.00  64.533816
# 26   13.0     0.0    15.0   0.000000    3.0    0.50  1.00  60.756112
# 27   10.0     0.0    50.0   0.000000    3.0    0.50  1.00  63.005645
# 28   16.0     0.0    95.0   0.000000    1.0    0.83  1.00  68.235885
# ...

# %%
# Print the list of cereal name with the following four (4) conditions :
cer_4conditions = df[ (df["calories"] > df["calories"].mean()) &
                      (df["protein"] > df["protein"].mean()) &
                      (df["carbo"] < df["carbo"].mean()) &
                      (df["potass"] < df["potass"].mean()) ]
cer_4conditions
# Out:
#                   name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 57  Honey Nut Cheerios   G    C     110.0      3.0  1.0   250.0    1.5   11.5
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 57    10.0    90.0      25.0    1.0     1.0  0.75  31.072217

# %%
# Print the Minimum of "Vitamins_Rate & sodium_Rate" by Cereal Type 考试这样写加分
Tab1 = df.groupby("type")[["vitamins", "sodium"]].min()
Tab1
# Out:
#       vitamins  sodium
# type
# C          0.0     0.0
# H          0.0     0.0

# %%
# Print the Mean of "Vitamins_Rate & sodium_Rate" by (Cereal Type & mfr )
Tab2 = df.groupby(["type", "mfr"])[["vitamins", "sodium"]].mean().reset_index()
Tab2
# Out:
#   type mfr   vitamins      sodium
# 0    C   G  36.538462  192.692308
# 1    C   K  33.067867  180.000000
# 2    C   N  10.000000   29.000000
# 3    C   P  25.000000  146.074561
# 4    C   Q  14.285714  105.714286
# 5    C   R  25.000000  198.125000
# 6    H   A  25.000000    0.000000
# 7    H   N   0.000000   80.000000
# 8    H   Q   0.000000    0.000000

# %%
# Using a loop (for _ in _) to select a column names from a list of columns:
for col in num_cols:
    print(col)
# Out:
# calories
# protein
# fat
# sodium
# fiber
# carbo
# sugars
# potass
# vitamins
# shelf
# weight
# cups
# rating

# %%
# Using a loop (for _ in _) to select a column names from a list of columns:对每一列，先打印列名，然后打印分隔线，最后打印该列的最小值。
for col in num_cols:
    print(col)
    print("==========")
    print("The min = ", df[col].min())
# Out:
# calories
# ...
# The min =  50.0
# protein
# ...
# The min =  1.0
# fat
# ...
# The min =  0.0
# sodium
# ...
# The min =  0.0
# fiber
# ...
# The min =  0.0
# carbo
# ...
# The min =  -1.0
# sugars
# ...
# The min =  -1.0
# potass
# ...
# The min =  -1.0
# vitamins
# ...
# The min =  0.0
# shelf
# ...
# The min =  1.0
# weight
# ...
# The min =  0.5
# cups
# ...
# The min =  0.25
# rating
# ...
# The min =  18.042851

# %%
# Using a loop (for _ in _) to select a column names from a list of columns:
for col in num_cols:
    print(col)
    print("=" * 10)
    print("The min = ", df[col].min())
    print("The max = ", df[col].max())
    print("=" * 30)
# Out:
# calories
# ...
# The min =  50.0
# The max =  160.0
# ...
# protein
# ...
# The min =  1.0
# The max =  6.0
# ...
# fat
# ...
# The min =  0.0
# The max =  5.0
# ...
# sodium
# ...
# The min =  0.0
# The max =  320.0
# ...
# fiber
# ...
# The min =  0.0
# The max =  14.0
# ...
# carbo
# ...
# The min =  -1.0
# The max =  23.0
# ...
# sugars
# ...
# The min =  -1.0
# The max =  15.0
# ...
# potass
# ...
# The min =  -1.0
# The max =  330.0
# ...
# vitamins
# ...
# The min =  0.0
# The max =  100.0
# ...
# shelf
# ...
# The min =  1.0
# The max =  3.0
# ...
# weight
# ...
# The min =  0.5
# The max =  1.5
# ...
# cups
# ...
# The min =  0.25
# The max =  1.5
# ...
# rating
# ...
# The min =  18.042851
# The max =  93.704912
# ...

# %% [markdown]
# session4

# %%
# upload csv file from my local disc
from google.colab import files
uploaded = files.upload()

# read csv file
import pandas as pd
df = pd.read_excel('Dominos_Pizza_Data.xlsx')
df
# Out:
#      <input type="file" id="files-15a8211b-5631-49c0-8d6b-589f05f153a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15a8211b-5631-49c0-8d6b-589f05f153a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# df dims
df.shape
# Out:
# (1301, 18)

# %%
# list of missing values by columns
df.isnull().sum()
# Out:
# Key                    0
# Date                   0
# mmdd                   0
# DayOfTheWeek           0
# Distance              11
# Timestamp              0
# Tip                    0
# OrderAmount           11
# TipPercent             0
# Housing                0
# GenderOfTipper         0
# Cash_Credit_Tip        0
# Web_Site               0
# PersonWhoDelivered     0
# Area                   0
# Satisfaction_Rate      7
# Recom_Rate            14
# month                  0
# dtype: int64

# %%
# df columns
df.columns
# df information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Key                 1301 non-null   int64
#  1   Date                1301 non-null   int64
#  2   mmdd                1301 non-null   int64
#  3   DayOfTheWeek        1301 non-null   object
#  4   Distance            1301 non-null   float64
#  5   Timestamp           1301 non-null   float64
#  6   Tip                 1301 non-null   float64
#  7   OrderAmount         1301 non-null   float64
#  8   TipPercent          1301 non-null   float64
#  9   Housing             1301 non-null   object
#  10  GenderOfTipper      1301 non-null   object
#  11  Cash_Credit_Tip     1301 non-null   object
#  12  Web_Site            1301 non-null   int64
#  13  PersonWhoDelivered  1301 non-null   object
#  14  Area                1301 non-null   object
# ...

# %%
# clean missing ( replace by the mean )
# select num columns
import numpy as np
num_cols = df.select_dtypes(include=np.number).columns
# replace by the mean
for col in num_cols:
    df[col] = df[col].fillna(df[col].mean())

df
# Out:
#        Key   Date  mmdd DayOfTheWeek  Distance  Timestamp   Tip  OrderAmount  \
# 0      712  42233   817       Monday       3.0   0.854167  4.13        12.87
# 1      339  42212   727       Monday       3.1   0.521528  3.36        15.44
# 2     1164  42287  1010     Saturday       3.1   0.762500  0.00        15.71
# 3     1189  42289  1012       Monday       2.5   0.756944  2.00        14.65
# 4     1085  42288  1011       Sunday       2.5   0.775000  5.22        16.78
# ...    ...    ...   ...          ...       ...        ...   ...          ...
# 1296  1181  42239   823       Sunday       1.2   0.758333  4.00        16.07
# 1297   465  42294  1017     Saturday       3.3   0.954861  3.92        16.08
# 1298   252  42217   801     Saturday       2.2   0.600000  3.00        17.03
# 1299   261  42221   805    Wednesday       2.8   0.592361  3.00        18.37
# 1300   610  42251   904       Friday       3.9   0.884722  5.00        33.20
#
# ...

# %%
# 检查处理后的缺失值情况
df.isnull().sum()
# Out:
# Key                   0
# Date                  0
# mmdd                  0
# DayOfTheWeek          0
# Distance              0
# Timestamp             0
# Tip                   0
# OrderAmount           0
# TipPercent            0
# Housing               0
# GenderOfTipper        0
# Cash_Credit_Tip       0
# Web_Site              0
# PersonWhoDelivered    0
# Area                  0
# Satisfaction_Rate     0
# Recom_Rate            0
# month                 0
# dtype: int64

# %%
# Find the Maximum "OrderAmount" "PersonWhoDelivered" name
pwd = df[ df["OrderAmount"] == df["OrderAmount"].max() ]
pwd
# Out:
#      Key   Date  mmdd DayOfTheWeek  Distance  Timestamp  Tip  OrderAmount  \
# 900  819  42268   921       Monday       3.7   0.827778  5.0        97.18
#
#      TipPercent   Housing GenderOfTipper Cash_Credit_Tip  Web_Site  \
# 900    5.145092  Business         Female          Credit         1
#
#     PersonWhoDelivered   Area  Satisfaction_Rate  Recom_Rate month
# 900              Angel  North           0.555407        0.58   Sep

# %%
# Find the Maximum "OrderAmount" "PersonWhoDelivered" name
pwd = df[ df["OrderAmount"] == df["OrderAmount"].max() ][["PersonWhoDelivered", "OrderAmount"]]
pwd
# Out:
#     PersonWhoDelivered  OrderAmount
# 900              Angel        97.18

# %%
# 豆包的的代码
max_order = df[df['OrderAmount'] == df['OrderAmount'].max()]
max_order_deliverer = max_order['PersonWhoDelivered'].values[0]
print("=== 1b) 数据处理结果 ===")
print(f"订单金额最大的配送员：{max_order_deliverer}")
# Out:
# === 1b) 数据处理结果 ===
# 订单金额最大的配送员：Angel

# %%
# Print the Total of "OrderAmount" & Total of "Distance" by "PersonWhoDelivered"
t_oa_dis_pwd = df.groupby("PersonWhoDelivered").sum()[["OrderAmount", "Distance"]]
t_oa_dis_pwd
# Out:
#                     OrderAmount    Distance
# PersonWhoDelivered
# Andria              6103.263170  657.828372
# Angel               7288.940170  776.860000
# Sammie              6733.250000  705.517349
# Thomas              8340.500283  830.854698

# %%
# Find the average "OrderAmount" by 'month' and by "Area"
O_M_A = df.groupby(["month", "Area"])[["OrderAmount"]].mean().reset_index()
O_M_A
# Out:
#    month      Area  OrderAmount
# 0    Aug  Downtown    21.203729
# 1    Aug      East    21.633395
# 2    Aug     North    20.289922
# 3    Aug     South    22.542307
# 4    Aug      West    22.029123
# 5    Jul  Downtown    21.011765
# 6    Jul      East    22.898043
# 7    Jul     North    22.028913
# 8    Jul     South    20.039687
# 9    Jul      West    26.974762
# 10   Nov  Downtown    17.213333
# 11   Nov      East    18.706667
# 12   Nov     North    24.368333
# 13   Nov     South    18.536667
# 14   Oct  Downtown    20.984002
# 15   Oct      East    22.185297
# 16   Oct     North    22.389130
# 17   Oct     South    22.386853
# 18   Oct      West    20.338136
# 19   Sep  Downtown    20.971335
# 20   Sep      East    23.745149
# 21   Sep     North    21.634872
# 22   Sep     South    22.553914
# 23   Sep      West    21.650870

# %%
# The graph of average of " Distance" of the "DayOfTheWeek"
# (X label name = " DayOfTheWeek" Y label name = average "Distance.)
import matplotlib.pyplot as plt
import seaborn as sns
graph1 = df.groupby("DayOfTheWeek")[["Distance"]].mean().reset_index()
graph1
# Out:
#   DayOfTheWeek  Distance
# 0       Friday  2.321174
# 1       Monday  2.184276
# 2     Saturday  2.318678
# 3       Sunday  2.229817
# 4     Thursday  2.221212
# 5      Tuesday  2.472728
# 6    Wednesday  2.454211

# %%
# The graph of average of " Distance" of the "DayOfTheWeek".
# (X label name = " DayOfTheWeek" Y label name = average "Distance.)
import matplotlib.pyplot as plt
import seaborn as sns
graph1 = df.groupby("DayOfTheWeek")[["Distance"]].mean().reset_index()
graph1.plot(x="DayOfTheWeek", y="Distance", kind="bar")
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
df = pd.read_excel('Dominos_Pizza_Data.xlsx')
# Out:
#      <input type="file" id="files-c44e4a6b-a7ab-4031-96c5-796fb491c053" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c44e4a6b-a7ab-4031-96c5-796fb491c053">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.columns

# The graph of average of " Distance" of the "DayOfTheweek".
# (X label name = " DayOfTheweek" Y label name = average "Distance.)
import matplotlib.pyplot as plt
import seaborn as sns
# 仅修正：列名DayOfTheweek → DayOfTheWeek（和你定义的df列名一致）
graph1 = df.groupby("DayOfTheWeek")[["Distance"]].mean().reset_index()
graph1.plot(x="DayOfTheWeek", y="Distance", kind="bar", color = "m")
plt.show()

# %% [markdown]
# project

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("umuttuygurr/e-commerce-customer-behavior-and-sales-analysis-tr")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 571k/571k [00:00<00:00, 41.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/umuttuygurr/e-commerce-customer-behavior-and-sales-analysis-tr/versions/2

# %%
import kagglehub
import pandas as pd
import os

# 1. First, download the dataset and get its storage path
path = kagglehub.dataset_download("umuttuygurr/e-commerce-customer-behavior-and-sales-analysis-tr")
print("Dataset path:", path)

# 2. Construct the full file path: dataset path + confirmed filename
csv_filename = "ecommerce_customer_behavior_dataset.csv"
full_path = os.path.join(path, csv_filename)
print("Full file path:", full_path)

# 3. Read the CSV file using the full path to avoid FileNotFound errors
df = pd.read_csv(full_path)

# 4. Verify that the data was loaded successfully
print("\n✅ Data loaded successfully!")
print("Dataset shape (rows, columns):", df.shape)
print("\nPreview of the first 5 rows:")
print(df.head())
# Out:
# Using Colab cache for faster access to the 'e-commerce-customer-behavior-and-sales-analysis-tr' dataset.
# Dataset path: /kaggle/input/e-commerce-customer-behavior-and-sales-analysis-tr
# Full file path: /kaggle/input/e-commerce-customer-behavior-and-sales-analysis-tr/ecommerce_customer_behavior_dataset.csv
#
# ✅ Data loaded successfully!
# Dataset shape (rows, columns): (5000, 18)
#
# Preview of the first 5 rows:
#      Order_ID Customer_ID        Date  Age  Gender      City Product_Category  \
# 0  ORD_001337  CUST_01337  2023-01-01   27  Female     Bursa             Toys
# 1  ORD_004885  CUST_04885  2023-01-01   42    Male     Konya             Toys
# 2  ORD_004507  CUST_04507  2023-01-01   43  Female    Ankara             Food
# 3  ORD_000645  CUST_00645  2023-01-01   32    Male  Istanbul      Electronics
# 4  ORD_000690  CUST_00690  2023-01-01   40  Female  Istanbul           Sports
#
#    Unit_Price  Quantity  Discount_Amount  Total_Amount    Payment_Method  \
# ...

# %%
# df dims
df.shape
# df columns
df.columns
# df information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Order_ID                  5000 non-null   object
#  1   Customer_ID               5000 non-null   object
#  2   Date                      5000 non-null   datetime64[ns]
#  3   Age                       5000 non-null   int64
#  4   Gender                    5000 non-null   object
#  5   City                      5000 non-null   object
#  6   Product_Category          5000 non-null   object
#  7   Unit_Price                5000 non-null   float64
#  8   Quantity                  5000 non-null   int64
#  9   Discount_Amount           5000 non-null   float64
#  10  Total_Amount              5000 non-null   float64
#  11  Payment_Method            5000 non-null   object
#  12  Device_Type               5000 non-null   object
# ...

# %%
# list of missing values by columns
df.isnull().sum()
# Out:
# Order_ID                    0
# Customer_ID                 0
# Date                        0
# Age                         0
# Gender                      0
# City                        0
# Product_Category            0
# Unit_Price                  0
# Quantity                    0
# Discount_Amount             0
# Total_Amount                0
# Payment_Method              0
# Device_Type                 0
# Session_Duration_Minutes    0
# Pages_Viewed                0
# Is_Returning_Customer       0
# Delivery_Time_Days          0
# Customer_Rating             0
# month                       0
# dtype: int64

# %%
# select the num columns
num_cols = df.select_dtypes(include=np.number).columns
num_cols
# Out:
# Index(['Age', 'Unit_Price', 'Quantity', 'Discount_Amount', 'Total_Amount',
#        'Session_Duration_Minutes', 'Pages_Viewed', 'Delivery_Time_Days',
#        'Customer_Rating'],
#       dtype='object')

# %%
# select the cat columns
cat_cols = df.select_dtypes(include=object).columns
cat_cols
# Out:
# Index(['Order_ID', 'Customer_ID', 'Gender', 'City', 'Product_Category',
#        'Payment_Method', 'Device_Type'],
#       dtype='object')

# %%
df = df.drop_duplicates()

# %%
# ---------------------- Step 2: Outlier Detection (IQR Method, Industry Standard) ----------------------
# Define a function to detect outliers (returns outlier row indices and counts for each column)
def detect_outliers(df, columns):
    outliers_info = {}
    for col in columns:
        # Calculate quartiles and IQR
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        # Outlier thresholds (below Q1 - 1.5*IQR or above Q3 + 1.5*IQR)
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        # Select outlier rows
        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
        outliers_info[col] = {
            "lower_bound": lower_bound,
            "upper_bound": upper_bound,
            "outliers_count": len(outliers),
            "outliers_index": outliers.index.tolist(),
            "outliers_data": outliers[col].values  # actual outlier values
        }
    return outliers_info

# Execute outlier detection
outliers_result = detect_outliers(df, num_cols)

# ---------------------- Step 3: Output Quantified Outlier Results ----------------------
print("\n===== Numeric Columns Outlier Statistics =====")
for col, info in outliers_result.items():
    print(f"\n[{col}]")
    print(f"  Normal range: {info['lower_bound']:.2f} ~ {info['upper_bound']:.2f}")
    print(f"  Outlier count: {info['outliers_count']}")
    if info['outliers_count'] > 0:
        print(f"  Example outliers: {info['outliers_data'][:5]}")  # show first 5 outliers
# Out:
# ===== Numeric Columns Outlier Statistics =====
#
# [Age]
#   Normal range: 4.50 ~ 64.50
#   Outlier count: 30
#   Example outliers: [66 65 73 71 75]
#
# [Unit_Price]
#   Normal range: -579.43 ~ 1169.94
#   Outlier count: 513
#   Example outliers: [2107.37 1784.75 1837.61 4136.98 1375.1 ]
#
# [Quantity]
#   Normal range: -2.00 ~ 6.00
#   Outlier count: 0
#
# [Discount_Amount]
#   Normal range: -13.14 ~ 21.90
#   Outlier count: 879
#   Example outliers: [229.28  62.15 490.25 100.24 156.33]
#
# [Total_Amount]
#   Normal range: -1163.25 ~ 2265.46
#   Outlier count: 546
#   Example outliers: [3778.05 4214.74 6648.75 4485.1  3518.89]
#
# [Session_Duration_Minutes]
#   Normal range: -8.50 ~ 35.50
#   Outlier count: 124
#   Example outliers: [48 36 38 52 36]
#
# [Pages_Viewed]
#   Normal range: 1.00 ~ 17.00
#   Outlier count: 14
#   Example outliers: [20 19 19 18 18]
#
# [Delivery_Time_Days]
#   Normal range: -2.00 ~ 14.00
#   Outlier count: 141
#   Example outliers: [17 17 15 16 16]
#
# ...

# %%
# Find numeric columns that contain negative values
negative_cols = [col for col in df.select_dtypes(include=['number']).columns if (df[col] < 0).any()]

if negative_cols:
    print("The following columns contain negative values:")
    for col in negative_cols:
        neg_count = (df[col] < 0).sum()
        print(f"{col}, negative value count: {neg_count}")
else:
    print("No columns contain negative values.")
# Out:
# No columns contain negative values.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

# Prepare data for plotting: extract values from each numeric column
plot_data = [df[col].values for col in num_cols]

# Draw boxplot
box = plt.boxplot(plot_data, labels=num_cols, patch_artist=True)

# Optional: color the boxes for better visualization
for patch in box['boxes']:
    patch.set_facecolor('lightblue')

plt.title("Numerical Columns Outlier Detection (Boxplot)", fontsize=14)
plt.xticks(rotation=45, ha='right')  # Rotate column names
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add horizontal grid lines for readability
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_303/2644993438.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   box = plt.boxplot(plot_data, labels=num_cols, patch_artist=True)
